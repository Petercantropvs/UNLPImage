# %% [markdown]
# # Trabajo Integrador 2023
# ## Grupo 35
# -------------------------------------------------------------------------------
# **Integrantes: Daniela Curin, Marcos Celi, Pedro Villegas**
#
# ------------------------------------------------------------------------------
